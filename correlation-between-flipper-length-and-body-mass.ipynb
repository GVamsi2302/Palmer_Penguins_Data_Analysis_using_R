# %%
library(tidyverse)
library(palmerpenguins)

# %% [markdown]
# Setting up my environment
# Notes: setting up my R environment by loading the ‘tidyverse’ and ‘palmerpenguins’ packages

# %%
palmerpenguins <- read_csv("/kaggle/input/palmer-penguins-using-r/penguins_size.csv")

# %%
head(palmerpenguins)

# %% [markdown]
# **Visualization**
#
# Here we go through a series of Visualization

# %% [markdown]
# **Flipper and body mass in purple**
#
# Here, we plot flipper length against body mass

# %%
ggplot(data=penguins,aes(x=flipper_length_mm,y=body_mass_g))+
geom_point(color="purple")

# %% [markdown]
# **Flipper and body mass by species**
#
# Here, we plot flipper against body mass and look at the breakdown by species

# %%
ggplot(data=penguins,aes(x=flipper_length_mm,y=body_mass_g))+
geom_point(aes(shape=species,color=species))

# %% [markdown]
# **Flipper and Body Mass by Species and Sex**
#
# Here, we plot flipper length and body mass and look at the breakdown by species and sex

# %%
ggplot(data=palmerpenguins)+
  geom_point(mapping=aes(x=flipper_length_mm, y=body_mass_g, color=species, shape=species))+facet_wrap(~sex)

# %% [markdown]
# **Title: Correlation Between Flipper Length and Body Mass in Penguins**
#
# **Correlation:** A strong and positive correlation exists between flipper length and body mass across all three penguin species.
#
# **Direct Relationship:** As the body mass of penguins increases, their flipper length also increases.
#
# **Significance of Body Mass:** This discovery highlights the importance of taking body mass into account when investigating flipper characteristics in penguins.
# Valuable Insights: The observed correlation offers valuable insights into the physical attributes of penguins.
#
# **Enhanced Understanding:** This correlation enhances our understanding of penguin biology and their adaptation to their environment.
